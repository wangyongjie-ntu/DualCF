# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import brewer2mpl
# %matplotlib inline

# %%
bmap = brewer2mpl.get_map("Set1", "qualitative", 7)                                                                                                                                                                                                                                                                          
colors = bmap.colors
Lcolors = colors[0:5]

for i in range(5):
    color = [i/255. for i in Lcolors[i]]
    Lcolors[i] = color

plt.rcParams['xtick.labelsize']= 17
plt.rcParams['ytick.labelsize']= 17
plt.rcParams["figure.figsize"] = (25,10)

# %%
synlinear_prediction_mean = [0.771, 0.86, 0.923, 0.957, 0.975, 0.986, 0.99]
synlinear_prediction_std = [0.157, 0.126, 0.076, 0.028, 0.012, 0.007, 0.004]
synlinear_pre_coreset_mean = [0.854, 0.937, 0.957, 0.97, 0.986, 0.992, 0.991]
synlinear_pre_coreset_std = [0.078, 0.04, 0.026, 0.021, 0.007, 0.006, 0.004]
synlinear_model_ext_mean = [0.944, 0.96, 0.971, 0.985, 0.99, 0.992, 0.993]
synlinear_model_ext_std = [0.04, 0.021, 0.017, 0.007, 0.003, 0.004, 0.005]
synlinear_doublecf_mean = [0.966, 0.967, 0.98, 0.981, 0.993, 0.998, 1.0]
synlinear_doublecf_std = [0.024, 0.026, 0.01, 0.009, 0.005, 0.004, 0.002]
synlinear_doublecfx_mean = [0.978, 0.988, 0.991, 0.992, 0.996, 0.995, 0.993]
synlinear_doublecfx_std = [0.024, 0.01, 0.006, 0.005, 0.005, 0.005, 0.005]
synlinear_xaxis = [5, 10, 20, 40, 80, 160, 320]

# %%
synnonlinear_prediction_mean = [0.769, 0.851, 0.887, 0.907, 0.924, 0.939, 0.954]
synnonlinear_prediction_std = [0.123, 0.072, 0.054, 0.022, 0.019, 0.024, 0.025]
synnonlinear_pre_coreset_mean = [0.726, 0.841, 0.911, 0.924, 0.938, 0.95, 0.96]
synnonlinear_pre_coreset_std = [0.112, 0.054, 0.024, 0.014, 0.019, 0.025, 0.027]
synnonlinear_model_ext_mean = [0.853, 0.887, 0.912, 0.93, 0.954, 0.968, 0.982]
synnonlinear_model_ext_std = [0.059, 0.048, 0.038, 0.035,0.034, 0.036, 0.025]
synnonlinear_doublecf_mean = [0.864, 0.89, 0.914, 0.939, 0.964,0.977,0.992]
synnonlinear_doublecf_std = [0.038, 0.037, 0.038, 0.036,0.036,0.034,0.02]
synnonlinear_doublecfx_mean = [0.861, 0.892, 0.927, 0.944, 0.957, 0.969, 0.98]
synnonlinear_doublecfx_std = [0.041, 0.038, 0.04, 0.037, 0.037, 0.035, 0.029]
synnonlinear_xaxis = [5, 10, 20, 40, 80, 160, 320]

# %%
gmsc_prediction_mean = [0.722, 0.792, 0.86, 0.892, 0.924, 0.946, 0.962]
gmsc_prediction_std = [0.092, 0.055, 0.031, 0.023, 0.014, 0.01, 0.007]
gmsc_pre_coreset_mean = [0.601, 0.7, 0.838, 0.881, 0.909, 0.935, 0.958]
gmsc_pre_coreset_std = [0.091, 0.112, 0.054, 0.038, 0.025, 0.021, 0.013]
gmsc_model_ext_mean = [0.865, 0.889, 0.921, 0.944, 0.959, 0.967, 0.973]
gmsc_model_ext_std = [0.033, 0.027, 0.018, 0.01, 0.008, 0.006, 0.005]
gmsc_doublecf_mean = [0.891, 0.905, 0.918, 0.931, 0.945, 0.952, 0.955]
gmsc_doublecf_std = [0.023, 0.02, 0.015, 0.013, 0.009, 0.009, 0.012]
gmsc_doublecfx_mean = [0.9, 0.905, 0.925, 0.939, 0.952, 0.962, 0.968]
gmsc_doublecfx_std = [0.022, 0.023, 0.014, 0.013, 0.009, 0.008, 0.006]
gmsc_xaxis = [5, 10, 20, 40, 80, 160, 320]

# %%
heloc_prediction_mean = [0.737, 0.786, 0.848, 0.878, 0.908, 0.925, 0.94]
heloc_prediction_std = [0.089, 0.062, 0.035, 0.025, 0.014, 0.009, 0.007]
heloc_pre_coreset_mean = [0.634, 0.76, 0.839, 0.884, 0.904, 0.924, 0.942]
heloc_pre_coreset_std = [0.089, 0.083, 0.044, 0.027, 0.014, 0.011, 0.008]
heloc_model_ext_mean = [0.84, 0.864, 0.885, 0.912, 0.932, 0.944, 0.953]
heloc_model_ext_std = [0.036, 0.03, 0.024, 0.016, 0.011, 0.007, 0.005]
heloc_doublecf_mean = [0.874, 0.883, 0.893, 0.898, 0.906, 0.915, 0.922]
heloc_doublecf_std = [0.022, 0.023, 0.017, 0.02, 0.02, 0.02, 0.016]
heloc_doublecfx_mean = [0.889, 0.894, 0.898, 0.915, 0.928, 0.938, 0.947]
heloc_doublecfx_std = [0.019, 0.018, 0.017, 0.015, 0.012, 0.009, 0.007]
heloc_xaxis = [5, 10, 20, 40, 80, 160, 320]

# %%
# boston_prediction_mean = [0.717, 0.786, 0.81, 0.844, 0.871, 0.877]
# boston_prediction_std = [0.12, 0.063, 0.049, 0.027, 0.02, 0.014]
# boston_pre_coreset_mean = [0.765, 0.743, 0.83, 0.846, 0.869, 0.877]
# boston_pre_coreset_std = [0.056, 0.072, 0.03, 0.024, 0.014, 0.013]
# boston_model_ext_mean = [0.768, 0.766, 0.798, 0.829, 0.881, 0.897]
# boston_model_ext_std = [0.067, 0.066, 0.051, 0.04, 0.029, 0.018]
# boston_doublecf_mean = [0.785, 0.797, 0.809, 0.868, 0.909, 0.938]
# boston_doublecf_std = [0.074, 0.063, 0.049, 0.038, 0.019, 0.016]
# boston_doublecfx_mean = [0.798, 0.827, 0.818, 0.867, 0.911, 0.939]
# boston_doublecfx_std = [0.063, 0.052, 0.055, 0.035, 0.023, 0.014]
# boston_xaxis = [5, 10, 20, 40, 80, 126, 160]

# boston_prediction_mean = [0.717, 0.797, 0.841, 0.875, 0.898, 0.909]
# boston_prediction_std = [0.12, 0.066, 0.053, 0.028, 0.021, 0.013]
# boston_pre_coreset_mean = [0.76, 0.753, 0.858, 0.846, 0.89, 0.912]
# boston_pre_coreset_std = [0.069, 0.072, 0.033, 0.034, 0.019, 0.011]
# boston_model_ext_mean = [0.823, 0.858, 0.879, 0.903, 0.914, 0.927]
# boston_model_ext_std = [0.058, 0.043, 0.028, 0.018, 0.015, 0.011]
# boston_doublecf_mean = [0.865, 0.878, 0.889, 0.896, 0.895, 0.897]
# boston_doublecf_std = [0.026, 0.024, 0.017, 0.015, 0.015, 0.014]
# boston_doublecfx_mean = [0.871, 0.883, 0.893, 0.907, 0.919, 0.934]
# boston_doublecfx_std = [0.029, 0.023, 0.021, 0.017, 0.014, 0.012]

# boston_prediction_mean = [0.706, 0.754, 0.805, 0.84, 0.871, 0.884]
# boston_prediction_std = [0.103, 0.07, 0.047, 0.029, 0.024, 0.013]
# boston_pre_coreset_mean = [0.732, 0.754, 0.811, 0.848, 0.868, 0.885]
# boston_pre_coreset_std = [0.07, 0.054, 0.028, 0.027, 0.016, 0.014]
# boston_model_ext_mean = [0.802, 0.824, 0.848, 0.874, 0.896, 0.903]
# boston_model_ext_std = [0.049, 0.039, 0.029, 0.023, 0.016, 0.014]
# boston_doublecf_mean = [0.833, 0.848, 0.86, 0.868, 0.871, 0.869]
# boston_doublecf_std = [0.052, 0.026, 0.022, 0.019, 0.016, 0.015]
# boston_doublecfx_mean = [0.843, 0.853, 0.862, 0.878, 0.888, 0.897]
# boston_doublecfx_std = [0.024, 0.023, 0.02, 0.016, 0.016, 0.014]

boston_prediction_mean = [0.706, 0.754, 0.805, 0.84, 0.871, 0.884]
boston_prediction_std = [0.103, 0.07, 0.047, 0.029, 0.024, 0.013]
boston_pre_coreset_mean = [0.732, 0.754, 0.811, 0.848, 0.868, 0.885]
boston_pre_coreset_std = [0.07, 0.054, 0.028, 0.027, 0.016, 0.014]
boston_model_ext_mean = [0.799, 0.817, 0.847, 0.877, 0.885, 0.897]
boston_model_ext_std = [0.046, 0.043, 0.033, 0.024, 0.021, 0.015]
boston_doublecf_mean = [0.836, 0.854, 0.863, 0.87, 0.876, 0.882]
boston_doublecf_std = [0.049, 0.03, 0.025, 0.02, 0.02, 0.024]
boston_doublecfx_mean = [0.844, 0.859, 0.865, 0.877, 0.889, 0.896]
boston_doublecfx_std = [0.025, 0.022, 0.02, 0.016, 0.017, 0.017]

boston_xaxis = [5, 10, 20, 40, 80, 126, 160]

# %%
from matplotlib.ticker import FormatStrFormatter
fig, axs = plt.subplots(2, 5)#, sharex=True, sharey = True)
xtick = np.arange(7)
    
# plot the [0, 0] syn_linear
axs[0,0].plot(xtick, synlinear_prediction_mean, color = Lcolors[0], label = "Steal-ML", marker = "s", markerfacecolor = 'none', markersize = 12)
axs[0,0].plot(xtick, synlinear_pre_coreset_mean, color = Lcolors[1], label = "Steal-ML (CoreSet)", marker = "o", markerfacecolor = 'none', markersize = 12)
axs[0,0].plot(xtick, synlinear_model_ext_mean, color = Lcolors[2], label = "Model Extraction", marker = "D", markerfacecolor = 'none', markersize = 12)
axs[0,0].plot(xtick, synlinear_doublecf_mean, color = Lcolors[3], label = "DualCF", marker = "X", markerfacecolor = 'none', markersize = 12)
axs[0,0].plot(xtick, synlinear_doublecfx_mean, color = Lcolors[4], label = "DualCFX", marker = "P", markerfacecolor = 'none', markersize = 12)


# plot [0, 1] std
axs[1,0].plot(xtick, synlinear_prediction_std, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[1,0].plot(xtick, synlinear_pre_coreset_std, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[1,0].plot(xtick, synlinear_model_ext_std, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[1,0].plot(xtick, synlinear_doublecf_std, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[1,0].plot(xtick, synlinear_doublecfx_std, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)


# plot the [1, 0] syn-nonlinear
axs[0,1].plot(xtick, synnonlinear_prediction_mean, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[0,1].plot(xtick, synnonlinear_pre_coreset_mean, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[0,1].plot(xtick, synnonlinear_model_ext_mean, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[0,1].plot(xtick, synnonlinear_doublecf_mean, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[0,1].plot(xtick, synnonlinear_doublecfx_mean, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)


# plot [1, 1] STD
axs[1,1].plot(xtick, synnonlinear_prediction_std, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[1,1].plot(xtick, synnonlinear_pre_coreset_std, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[1,1].plot(xtick, synnonlinear_model_ext_std, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[1,1].plot(xtick, synnonlinear_doublecf_std, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[1,1].plot(xtick, synnonlinear_doublecfx_std, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)

# plot the [2, 0] GMSC
axs[0,2].plot(xtick, gmsc_prediction_mean, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[0,2].plot(xtick, gmsc_pre_coreset_mean, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[0,2].plot(xtick, gmsc_model_ext_mean, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[0,2].plot(xtick, gmsc_doublecf_mean, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[0,2].plot(xtick, gmsc_doublecfx_mean, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)

 
# plot [2, 1] STD
axs[1,2].plot(xtick, gmsc_prediction_std, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[1,2].plot(xtick, gmsc_pre_coreset_std, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[1,2].plot(xtick, gmsc_model_ext_std, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[1,2].plot(xtick, gmsc_doublecf_std, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[1,2].plot(xtick, gmsc_doublecfx_std, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)


# plot the [3, 0] Heloc-10
axs[0,3].plot(xtick, heloc_prediction_mean, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[0,3].plot(xtick, heloc_pre_coreset_mean, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[0,3].plot(xtick, heloc_model_ext_mean, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[0,3].plot(xtick, heloc_doublecf_mean, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[0,3].plot(xtick, heloc_doublecfx_mean, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)

 
# plot [3, 1] STD
axs[1,3].plot(xtick, heloc_prediction_std, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[1,3].plot(xtick, heloc_pre_coreset_std, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[1,3].plot(xtick, heloc_model_ext_std, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[1,3].plot(xtick, heloc_doublecf_std, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[1,3].plot(xtick, heloc_doublecfx_std, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)

# plot [4, 0] Boston
xtick1 = [0, 1, 2, 3, 4, 6]
axs[0,4].plot(xtick[0:6], boston_prediction_mean, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[0,4].plot(xtick[0:6], boston_pre_coreset_mean, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[0,4].plot(xtick[0:6], boston_model_ext_mean, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[0,4].plot(xtick1, boston_doublecf_mean, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[0,4].plot(xtick1, boston_doublecfx_mean, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)

 
# plot [2, 1] STD

axs[1,4].plot(xtick[0:6], boston_prediction_std, color = Lcolors[0], marker = "s", markerfacecolor = 'none', markersize = 12)
axs[1,4].plot(xtick[0:6], boston_pre_coreset_std, color = Lcolors[1], marker = "o", markerfacecolor = 'none', markersize = 12)
axs[1,4].plot(xtick[0:6], boston_model_ext_std, color = Lcolors[2], marker = "D", markerfacecolor = 'none', markersize = 12)
axs[1,4].plot(xtick1, boston_doublecf_std, color = Lcolors[3], marker = "X", markerfacecolor = 'none', markersize = 12)
axs[1,4].plot(xtick1, boston_doublecfx_std, color = Lcolors[4], marker = "P", markerfacecolor = 'none', markersize = 12)


axs[0,0].set_ylabel(r'Agreement$\rightarrow$', fontsize = 17)
axs[1,0].set_ylabel(r'Std$\leftarrow$', fontsize = 17)

axs[0,0].set_title(r"Syn-Linear", fontsize = 17)
axs[0,1].set_title(r"Syn-Nonliear", fontsize = 17)
axs[0,2].set_title(r"GMSC", fontsize = 17)
axs[0,3].set_title(r"Heloc-10", fontsize = 17)
axs[0,4].set_title(r"Boston-Housing", fontsize = 17)

axs[1,0].set_xticks(xtick)
axs[1,0].set_xticklabels(synlinear_xaxis)
axs[1,1].set_xticks(xtick)
axs[1,1].set_xticklabels(synnonlinear_xaxis)
axs[1,2].set_xticks(xtick)
axs[1,2].set_xticklabels(gmsc_xaxis)
axs[1,3].set_xticks(xtick)
axs[1,3].set_xticklabels(heloc_xaxis)
axs[1,4].set_xticks(xtick)
axs[1,4].set_xticklabels(boston_xaxis)

axs[0,0].set_xticks(xtick)
axs[0,0].set_xticklabels(synlinear_xaxis)
axs[0,1].set_xticks(xtick)
axs[0,1].set_xticklabels(synnonlinear_xaxis)
axs[0,2].set_xticks(xtick)
axs[0,2].set_xticklabels(gmsc_xaxis)
axs[0,3].set_xticks(xtick)
axs[0,3].set_xticklabels(heloc_xaxis)
axs[0,4].set_xticks(xtick)
axs[0,4].set_xticklabels(boston_xaxis)

axs[1, 0].set_xlabel("#Querys", fontsize = 17)
axs[1, 1].set_xlabel("#Querys", fontsize = 17)
axs[1, 2].set_xlabel("#Querys", fontsize = 17)
axs[1, 3].set_xlabel("#Querys", fontsize = 17)
axs[1, 4].set_xlabel("#Querys", fontsize = 17)
axs[1, 0].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#axs[2, 2].tick_params(axis = 'y', which = 'major', labelsize = 12)
#axs[0, 0].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))


#axs[0,0].legend(ncol = 5, loc = "lower center",bbox_to_anchor = (0.5, 1.0), fontsize = 14, columnspacing = 1)
handles, labels = axs[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol = 5, fontsize = 17, columnspacing = 3, bbox_to_anchor = (0.5, 0.0))
#fig.tight_layout()
#plt.savefig("experiments.png", bbox_inches = 'tight')
plt.savefig("experiments.pdf", dpi = 600, bbox_inches = 'tight')
plt.show()
