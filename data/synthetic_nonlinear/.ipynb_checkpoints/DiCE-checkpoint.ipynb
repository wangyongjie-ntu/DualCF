# %%
import torch
import dice_ml
import pandas as pd
import numpy as np

# %%
dquery = pd.read_csv("synthetic_query.csv")
dtrain = pd.read_csv("synthetic_train.csv")

# %%
columns = dtrain.columns.tolist()
d = dice_ml.Data(dataframe = dtrain, continuous_features = columns[0:2], outcome_name = 'Y')

# %%
backend = 'PYT'
model_path = "synthetic.pt"
m = dice_ml.Model(model_path = model_path, backend = backend)
exp = dice_ml.Dice(d, m)

cf_df = None

# %%
print(columns[0:2])
# Out:
# ['X1', 'X2']

# %%
for i in range(len(dquery)):
    print(i)
    query_instance = dquery.iloc[i, 0:2].to_dict()
    dice_exp = exp.generate_counterfactuals(query_instance, total_CFs= 1, desired_class='opposite', verbose = False, posthoc_sparsity_algorithm=None,
                                           max_iter= 1000, learning_rate=0.1)
    
    if cf_df is None:
        cf_df = dice_exp.cf_examples_list[0].final_cfs_df
    else:
        cf_df = pd.concat((cf_df, dice_exp.cf_examples_list[0].final_cfs_df))
# Out:
# 0
# Diverse Counterfactuals found! total time taken: 00 min 02 sec
# 1
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 2
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 3
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 4
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 5
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 6
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 7
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 8
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 9
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 10
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 11
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 12
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 13
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 14
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 15
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 16
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 17
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 18
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 19
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 20
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 21
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 22
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 23
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 24
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 25
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 26
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 27
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 28
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 29
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 30
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 31
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 32
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 33
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 34
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 35
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 36
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 37
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 38
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 39
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 40
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 41
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 42
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 43
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 44
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 45
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 46
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 47
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 48
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 49
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 50
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 51
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 52
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 53
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 54
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 55
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 56
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 57
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 58
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 59
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 60
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 61
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 62
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 63
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 64
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 65
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 66
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 67
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 68
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 69
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 70
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 71
# Diverse Counterfactuals found! total time taken: 00 min 01 sec
# 72
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 73
# No Counterfactuals found for the given configuation,  perhaps try with different values of proximity (or diversity) weights or learning rate... ; total time taken: 00 min 01 sec
# 74
# Diverse Counterfactuals found! total time taken: 00 min 02 sec
# 75
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-17810817f81d> in <module>
#       3     query_instance = dquery.iloc[i, 0:2].to_dict()
#       4     dice_exp = exp.generate_counterfactuals(query_instance, total_CFs= 1, desired_class='opposite', verbose = False, posthoc_sparsity_algorithm=None,
# ----> 5                                            max_iter= 1000)
#       6
#       7     if cf_df is None:
#
# ~/anaconda3/lib/python3.7/site-packages/dice_ml-0.6.1-py3.7.egg/dice_ml/explainer_interfaces/dice_pytorch.py in generate_counterfactuals(self, query_instance, total_CFs, desired_class, proximity_weight, diversity_weight, categorical_penalty, algorithm, features_to_vary, permitted_range, yloss_type, diversity_loss_type, feature_weights, optimizer, learning_rate, min_iter, max_iter, project_iter, loss_diff_thres, loss_converge_maxiter, verbose, init_near_query_instance, tie_random, stopping_threshold, posthoc_sparsity_param, posthoc_sparsity_algorithm)
#     127                 query_instance, desired_class, optimizer, learning_rate, min_iter, max_iter,
#     128                 project_iter, loss_diff_thres, loss_converge_maxiter, verbose, init_near_query_instance,
# --> 129                 tie_random, stopping_threshold, posthoc_sparsity_param, posthoc_sparsity_algorithm)
#     130
#     131         counterfactual_explanations = exp.CounterfactualExamples(
#
# ~/anaconda3/lib/python3.7/site-packages/dice_ml-0.6.1-py3.7.egg/dice_ml/explainer_interfaces/dice_pytorch.py in find_counterfactuals(self, query_instance, desired_class, optimizer, learning_rate, min_iter, max_iter, project_iter, loss_diff_thres, loss_converge_maxiter, verbose, init_near_query_instance, tie_random, stopping_threshold, posthoc_sparsity_param, posthoc_sparsity_algorithm)
#     484
#     485                 # get loss and backpropogate
# --> 486                 loss_value = self.compute_loss()
#     487                 self.loss.backward()
#     488
#
# ~/anaconda3/lib/python3.7/site-packages/dice_ml-0.6.1-py3.7.egg/dice_ml/explainer_interfaces/dice_pytorch.py in compute_loss(self)
#     317     def compute_loss(self):
#     318         """Computes the overall loss"""
# --> 319         self.yloss = self.compute_yloss()
#     320         self.proximity_loss = self.compute_proximity_loss() if self.proximity_weight > 0 else 0.0
#     321         self.diversity_loss = self.compute_diversity_loss() if self.diversity_weight > 0 else 0.0
#
# ~/anaconda3/lib/python3.7/site-packages/dice_ml-0.6.1-py3.7.egg/dice_ml/explainer_interfaces/dice_pytorch.py in compute_yloss(self)
#     243             elif self.yloss_type == "hinge_loss":
#     244                 temp_logits = torch.log(
# --> 245                     (abs(self.get_model_output(self.cfs[i]) - 0.000001)) /
#     246                     (1 - abs(self.get_model_output(self.cfs[i]) - 0.000001)))
#     247                 criterion = torch.nn.ReLU()
#
# ~/anaconda3/lib/python3.7/site-packages/dice_ml-0.6.1-py3.7.egg/dice_ml/explainer_interfaces/dice_pytorch.py in get_model_output(self, input_instance)
#     141     def get_model_output(self, input_instance):
#     142         """get output probability of ML model"""
# --> 143         return self.model.get_output(input_instance)[(self.num_output_nodes-1):]
#     144
#     145     def predict_fn(self, input_instance):
#
# ~/anaconda3/lib/python3.7/site-packages/dice_ml-0.6.1-py3.7.egg/dice_ml/model_interfaces/pytorch_model.py in get_output(self, input_tensor, transform_data)
#      33             input_tensor = torch.tensor(self.transformer.transform(input_tensor)).float()
#      34
# ---> 35         return self.model(input_tensor).float()
#      36
#      37     def set_eval_mode(self):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
# -> 1692         output = input.matmul(weight.t())
#    1693         if bias is not None:
#    1694             output += bias
#
# KeyboardInterrupt:
