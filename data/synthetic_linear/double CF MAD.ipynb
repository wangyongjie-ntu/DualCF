# %%
import numpy as np
import pandas as pd
import torch
import random
import copy
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score, f1_score
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
dquery = np.load("synthetic_query_v1.npy").astype(np.float32)
dtest = np.load("synthetic_test_v1.npy").astype(np.float32)

# %%
dcf = np.load("MAD/synthetic-plaincf-mad.npy").astype(np.float32)
dccf = np.load("MAD/synthetic-plaincf2-mad.npy").astype(np.float32)

# %%
query_x, query_y = dquery[:, 0:2], dquery[:, 2:3]
cf_x, cf_y = dcf[:, 0:2], dcf[:, 2:3]
ccf_x, ccf_y = dccf[:, 0:2], dccf[:, 2:3]
test_x, test_y = dtest[:, 0:2], dtest[:, 2:3]

# %%
scaler = MinMaxScaler()
query_x = scaler.fit_transform(query_x)
test_x = scaler.transform(test_x)
cf_x = scaler.transform(cf_x)
ccf_x = scaler.transform(ccf_x)

# %%
print(scaler.min_, scaler.data_max_, scaler.data_min_)
# Out:
# [-0.002344   -0.00155307] [5.9944053 5.992553 ] [0.01401805 0.00929243]

# %% [markdown]
# # Select subset of query for training

# %%
idx = [456, 341, 63]

# %%
cf_sx, cf_sy = cf_x[idx], cf_y[idx]
ccf_sx, ccf_sy = ccf_x[idx], ccf_y[idx]

train_x, train_y = np.concatenate((cf_sx, ccf_sx), axis = 0), np.concatenate((cf_sy, ccf_sy), axis = 0)

# %%
print(cf_sy, ccf_sy)
# Out:
# [[0.]
#  [0.]
#  [0.]] [[1.]
#  [1.]
#  [1.]]

# %%
print(cf_sx, ccf_sx)
# Out:
# [[0.54611546 0.7388458 ]
#  [0.34211525 0.34106946]
#  [0.5544761  0.75388783]] [[0.60798436 0.68034935]
#  [0.43408254 0.34106946]
#  [0.6029679  0.67032135]]

# %%
print(cf_sy, ccf_sy)
# Out:
# [[0.]
#  [0.]
#  [0.]] [[1.]
#  [1.]
#  [1.]]

# %%
Query = TensorDataset(torch.from_numpy(train_x), torch.from_numpy(train_y))
Test = TensorDataset(torch.from_numpy(test_x), torch.from_numpy(test_y))

# %%
query_loader = DataLoader(Query, batch_size  = 32)
test_loader = DataLoader(Test, batch_size = 32)

# %%
print(dcf)
# Out:
# [[2.27 2.46 0.  ]
#  [1.98 1.89 0.  ]
#  [2.44 2.78 0.  ]
#  ...
#  [2.53 2.96 0.  ]
#  [3.76 5.35 0.  ]
#  [1.99 1.9  0.  ]]

# %%
def train(model, iterator, optimizer, criterion, device):

    epoch_loss = 0
    model.train()
    prediction = []
    label = []

    for batch_idx, (data, target) in enumerate(iterator):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        preds = torch.round(output)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item() * len(target)
        label.extend(target.tolist())
        prediction.extend(preds.reshape(-1).tolist())

    acc = accuracy_score(label, prediction)
    f1 = f1_score(label, prediction)

    return epoch_loss / len(iterator.dataset), acc, f1

def evaluate(model, iterator, criterion, device):

    epoch_loss = 0
    model.eval()
    prediction = []
    label = []

    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(iterator):

            data, target = data.to(device), target.to(device)
            output = model(data)
            _, preds = torch.max(output, 1)
            preds = torch.round(output)
            loss = criterion(output, target)
            epoch_loss += loss.item() * len(target)
            label.extend(target.tolist())
            prediction.extend(preds.reshape(-1).tolist())
            
    acc = accuracy_score(label, prediction)
    f1 = f1_score(label, prediction)

    return epoch_loss / len(iterator.dataset), acc, f1

# %%
model = nn.Sequential(
    nn.Linear(2, 10),
    nn.ReLU(),
    nn.Linear(10, 1),
    nn.Sigmoid(),
)


optimizer = optim.Adam(model.parameters(), lr = 0.005)
criterion = nn.BCELoss()
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
model = model.to(device)
criterion = criterion.to(device)

best_f1 = -float('inf')
best_model = None
best_acc = -float('inf')

for epoch in range(500):

    train_loss, train_acc, train_f1 = train(model, query_loader, optimizer, criterion, device)
    
    if epoch % 50 == 0:
        print(f'Epoch: {epoch} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Train F1: {train_f1:.4f}')
# Out:
# Epoch: 0 | Train Loss: 0.6895 | Train Acc: 0.5000 | Train F1: 0.6667
# Epoch: 50 | Train Loss: 0.6599 | Train Acc: 0.8333 | Train F1: 0.8571
# Epoch: 100 | Train Loss: 0.6026 | Train Acc: 0.8333 | Train F1: 0.8571
# Epoch: 150 | Train Loss: 0.5201 | Train Acc: 1.0000 | Train F1: 1.0000
# Epoch: 200 | Train Loss: 0.4234 | Train Acc: 1.0000 | Train F1: 1.0000
# Epoch: 250 | Train Loss: 0.3270 | Train Acc: 1.0000 | Train F1: 1.0000
# Epoch: 300 | Train Loss: 0.2410 | Train Acc: 1.0000 | Train F1: 1.0000
# Epoch: 350 | Train Loss: 0.1732 | Train Acc: 1.0000 | Train F1: 1.0000
# Epoch: 400 | Train Loss: 0.1251 | Train Acc: 1.0000 | Train F1: 1.0000
# Epoch: 450 | Train Loss: 0.0922 | Train Acc: 1.0000 | Train F1: 1.0000

# %%
test_x = torch.from_numpy(test_x)
test_pred = torch.round(model(test_x)).detach().numpy()
agree = (test_pred == test_y).sum() / test_x.shape[0]
print(agree)
# Out:
# 0.9866666666666667

# %%
h= 0.02
x_min, x_max = dquery[:, 0].min() - .5, dquery[:, 0].max() + .5
y_min, y_max = dquery[:, 1].min() - .5, dquery[:, 1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                 np.arange(y_min, y_max, h))

# %%
dplot = np.c_[xx.ravel(), yy.ravel()]
_dplot = scaler.transform(dplot).astype(np.float32)
_dplot = torch.from_numpy(_dplot)
S = torch.round(model(_dplot)).detach().numpy()

# %%
S = S.reshape(xx.shape)

# %%
sample_positive = np.load("sample_positive.npy")
sample_negative = np.load("sample_negative.npy")

# %%
fig, ax = plt.subplots()
ax.tick_params(axis='both', which='major', labelsize=12)
fig.set_size_inches(5, 5)

matplotlib.rcParams['contour.negative_linestyle'] = 'solid'
SS = S.round()
CS = ax.contour(xx, yy, SS, colors = "black")
#ax.scatter(sample_positive[:, 0], sample_positive[:, 1], c = '#1f77b4', label = "Class 0")
#ax.scatter(sample_negative[:, 0], sample_negative[:, 1], c = '#9467bd', label = "Class 1")
ax.scatter(sample_positive[:, 0], sample_positive[:, 1], edgecolors = '#1f77b4', label = "class 0", facecolors='none')
ax.scatter(sample_negative[:, 0], sample_negative[:, 1], edgecolors = '#9467bd', label = "class 1", facecolors = 'none')

#ax.scatter(raw[idx, 0], raw[idx, 1], marker = "o", label = "Input")

#ax.scatter(dquery[idx, 0], dquery[idx, 1], s= 50, color = '#ff7f0e', label = "Input")
ax.scatter(dcf[idx, 0], dcf[idx, 1], marker = "^", s = 200, label = "CF", color = '#2ca02c')
ax.scatter(dccf[idx, 0], dccf[idx, 1], marker = "h", s = 200, label = "CCF", color = '#d62728')
ax.legend(loc = 'upper right', fontsize = 14, handletextpad = 0, columnspacing = 0, borderpad = 0)
ax.set_title("Double CF: {:.2f}% agreement".format(agree * 100), fontsize = 15)
plt.tight_layout()
plt.savefig("Double CF MAD.pdf", dpi = 300)
plt.show()

# %%
print(dcf[idx])
# Out:
# [[3.28 4.43 0.  ]
#  [2.06 2.05 0.  ]
#  [3.33 4.52 0.  ]]
